# %%
from bs4 import BeautifulSoup

# %%
url="https://www.worldometers.info/coronavirus/"

# %%
import requests

# %%
contents=requests.get(url).content

# %%
soup=BeautifulSoup(contents,'html.parser')

# %%
covid_data=soup.find('tbody').find_all('tr')

# %%
covid_data[8]
# Out:
# <tr style="">
# <td style="font-size:12px;color: grey;text-align:center;vertical-align:middle;">1</td>
# <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/us/">USA</a></td>
# <td style="font-weight: bold; text-align:right">96,149,016</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="font-weight: bold; text-align:right;">1,069,748 </td>
# <td style="font-weight: bold;
#                                     text-align:right;"></td>
# <td style="font-weight: bold; text-align:right">91,873,169</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="text-align:right;font-weight:bold;">3,206,099</td>
# <td style="font-weight: bold; text-align:right">4,029</td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right">1,100,355,942</td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right"> </td>
# <td data-continent="North America" style="display:none">North America</td>
# <td></td><td></td><td></td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right"></td>
# </tr>

# %%
whole_data=[]
for item in range(8,len(covid_data)):
    data=[]
    dat=covid_data[item].find_all('td')
    for i in dat:
        text=(i.text)
        data.append(text)
    whole_data.append(data)

# %%
whole_data
# Out:
# [['1',
#   'USA',
#   '96,149,016',
#   '',
#   '1,069,748 ',
#   '',
#   '91,873,169',
#   '',
#   '3,206,099',
#   '4,029',
#   '',
#   '',
#   '1,100,355,942',
#   '',
#   ' ',
#   'North America',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2',
#   'India',
#   '44,429,258',
#   '',
#   '527,829 ',
#   '',
#   '43,825,024',
#   '',
#   '76,405',
#   '698',
#   '31,526',
#   '375',
#   '885,528,970',
#   '628,359',
#   '1,409,273,386 ',
#   'Asia',
#   '32',
#   '2,670',
#   '2',
#   '',
#   '',
#   '54'],
#  ['3',
#   'France',
#   '34,509,961',
#   '',
#   '154,039 ',
#   '',
#   '33,990,930',
#   '',
#   '364,992',
#   '869',
#   '526,187',
#   '2,349',
#   '271,490,188',
#   '4,139,517',
#   '65,584,999 ',
#   'Europe',
#   '2',
#   '426',
#   '0',
#   '',
#   '',
#   '5,565'],
#  ['4',
#   'Brazil',
#   '34,414,011',
#   '',
#   '683,914 ',
#   '',
#   '33,457,359',
#   '',
#   '272,738',
#   '8,318',
#   '159,458',
#   '3,169',
#   '63,776,166',
#   '295,508',
#   '215,818,679 ',
#   'South America',
#   '6',
#   '316',
#   '3',
#   '',
#   '',
#   '1,264'],
#  ['5',
#   'Germany',
#   '32,095,854',
#   '',
#   '147,223 ',
#   '',
#   '31,204,400',
#   '',
#   '744,231',
#   '1,406',
#   '380,455',
#   '1,745',
#   '122,332,384',
#   '1,450,093',
#   '84,361,727 ',
#   'Europe',
#   '3',
#   '573',
#   '1',
#   '',
#   '',
#   '8,822'],
#  ['6',
#   'UK',
#   '23,492,875',
#   '',
#   '187,761 ',
#   '',
#   '23,198,168',
#   '+8,196',
#   '106,946',
#   '146',
#   '342,186',
#   '2,735',
#   '522,526,476',
#   '7,610,882',
#   '68,655,180 ',
#   'Europe',
#   '3',
#   '366',
#   '0',
#   '',
#   '',
#   '1,558'],
#  ['7',
#   'S. Korea',
#   '23,246,398',
#   '+103,919',
#   '26,764 ',
#   '+75',
#   '21,209,666',
#   '+124,444',
#   '2,009,968',
#   '569',
#   '452,579',
#   '521',
#   '15,804,065',
#   '307,686',
#   '51,364,333 ',
#   'Asia',
#   '2',
#   '1,919',
#   '3',
#   '2,023',
#   '1',
#   '39,132'],
#  ['8',
#   'Italy',
#   '21,845,943',
#   '',
#   '175,505 ',
#   '',
#   '21,010,197',
#   '',
#   '660,241',
#   '226',
#   '362,467',
#   '2,912',
#   '242,250,595',
#   '4,019,414',
#   '60,270,134 ',
#   'Europe',
#   '3',
#   '343',
#   '0',
#   '',
#   '',
#   '10,955'],
#  ['9',
#   'Russia',
#   '19,482,648',
#   '',
#   '384,254 ',
#   '',
#   '18,557,580',
#   '',
#   '540,814',
#   '2,300',
#   '133,379',
#   '2,631',
#   '273,400,000',
#   '1,871,713',
#   '146,069,399 ',
#   'Europe',
#   '7',
#   '380',
#   '1',
#   '',
#   '',
#   '3,702'],
#  ['10',
#   'Japan',
#   '18,632,422',
#   '',
#   '39,253 ',
#   '',
#   '16,678,164',
#   '',
#   '1,915,005',
#   '618',
#   '148,298',
#   '312',
#   '70,939,816',
#   '564,620',
#   '125,641,741 ',
#   'Asia',
#   '7',
#   '3,201',
#   '2',
#   '',
#   '',
#   '15,242'],
#  ['11',
#   'Turkey',
#   '16,671,848',
#   '',
#   '100,400 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '975',
#   '193,192',
#   '1,163',
#   '162,743,369',
#   '1,885,854',
#   '86,296,896 ',
#   'Asia',
#   '5',
#   '860',
#   '1',
#   '',
#   '',
#   '2,888'],
#  ['12',
#   'Spain',
#   '13,342,530',
#   '',
#   '112,600 ',
#   '',
#   '13,113,979',
#   '',
#   '115,951',
#   '339',
#   '285,134',
#   '2,406',
#   '471,036,328',
#   '10,066,206',
#   '46,793,829 ',
#   'Europe',
#   '4',
#   '416',
#   '0',
#   '',
#   '',
#   '2,478'],
#  ['13',
#   'Vietnam',
#   '11,408,952',
#   '',
#   '43,117 ',
#   '',
#   '10,170,271',
#   '',
#   '1,195,564',
#   '137',
#   '114,977',
#   '435',
#   '85,826,548',
#   '864,944',
#   '99,227,893 ',
#   'Asia',
#   '9',
#   '2,301',
#   '1',
#   '',
#   '',
#   '12,049'],
#  ['14',
#   'Australia',
#   '10,029,103',
#   '+11,066',
#   '13,899 ',
#   '+65',
#   '9,872,614',
#   '',
#   '142,590',
#   '84',
#   '383,696',
#   '532',
#   '78,179,753',
#   '2,991,018',
#   '26,138,175 ',
#   'Australia/Oceania',
#   '3',
#   '1,881',
#   '0',
#   '423',
#   '2',
#   '5,455'],
#  ['15',
#   'Argentina',
#   '9,678,225',
#   '',
#   '129,711 ',
#   '',
#   '9,477,279',
#   '+4,456',
#   '71,235',
#   '456',
#   '209,983',
#   '2,814',
#   '35,716,069',
#   '774,913',
#   '46,090,433 ',
#   'South America',
#   '5',
#   '355',
#   '1',
#   '',
#   '',
#   '1,546'],
#  ['16',
#   'Netherlands',
#   '8,385,110',
#   '',
#   '22,599 ',
#   '',
#   '8,313,977',
#   '',
#   '48,534',
#   '34',
#   '487,035',
#   '1,313',
#   '21,107,399',
#   '1,225,989',
#   '17,216,635 ',
#   'Europe',
#   '2',
#   '762',
#   '1',
#   '',
#   '',
#   '2,819'],
#  ['17',
#   'Iran',
#   '7,527,499',
#   '',
#   '143,820 ',
#   '',
#   '7,292,566',
#   '',
#   '91,113',
#   '1,104',
#   '87,212',
#   '1,666',
#   '53,730,223',
#   '622,509',
#   '86,312,319 ',
#   'Asia',
#   '11',
#   '600',
#   '2',
#   '',
#   '',
#   '1,056'],
#  ['18',
#   'Mexico',
#   '7,021,598',
#   '+6,223',
#   '329,456 ',
#   '+55',
#   '6,274,762',
#   '+6,855',
#   '417,380',
#   '4,798',
#   '53,252',
#   '2,499',
#   '18,161,607',
#   '137,739',
#   '131,855,081 ',
#   'North America',
#   '19',
#   '400',
#   '7',
#   '47',
#   '0.4',
#   '3,165'],
#  ['19',
#   'Indonesia',
#   '6,354,245',
#   '',
#   '157,541 ',
#   '',
#   '6,151,650',
#   '',
#   '45,054',
#   '2,771',
#   '22,713',
#   '563',
#   '106,645,001',
#   '381,197',
#   '279,763,274 ',
#   'Asia',
#   '44',
#   '1,776',
#   '3',
#   '',
#   '',
#   '161'],
#  ['20',
#   'Colombia',
#   '6,299,595',
#   '',
#   '141,519 ',
#   '',
#   '6,122,457',
#   '',
#   '35,619',
#   '342',
#   '121,023',
#   '2,719',
#   '36,279,188',
#   '696,968',
#   '52,052,892 ',
#   'South America',
#   '8',
#   '368',
#   '1',
#   '',
#   '',
#   '684'],
#  ['21',
#   'Poland',
#   '6,173,059',
#   '',
#   '117,059 ',
#   '',
#   '5,335,962',
#   '',
#   '720,038',
#   '2,782',
#   '163,493',
#   '3,100',
#   '36,947,074',
#   '978,543',
#   '37,757,235 ',
#   'Europe',
#   '6',
#   '323',
#   '1',
#   '',
#   '',
#   '19,070'],
#  ['22',
#   'Portugal',
#   '5,417,101',
#   '',
#   '24,845 ',
#   '',
#   '5,319,782',
#   '',
#   '72,474',
#   '61',
#   '534,620',
#   '2,452',
#   '43,527,258',
#   '4,295,759',
#   '10,132,611 ',
#   'Europe',
#   '2',
#   '408',
#   '0',
#   '',
#   '',
#   '7,153'],
#  ['23',
#   'Taiwan',
#   '5,273,449',
#   '',
#   '9,893 ',
#   '',
#   '4,791,748',
#   '',
#   '471,808',
#   '',
#   '220,557',
#   '414',
#   '24,248,455',
#   '1,014,166',
#   '23,909,738 ',
#   'Asia',
#   '5',
#   '2,417',
#   '1',
#   '',
#   '',
#   '19,733'],
#  ['24',
#   'Ukraine',
#   '5,044,941',
#   '',
#   '108,803 ',
#   '',
#   '4,922,363',
#   '+777',
#   '13,775',
#   '177',
#   '116,869',
#   '2,520',
#   '19,521,252',
#   '452,222',
#   '43,167,431 ',
#   'Europe',
#   '9',
#   '397',
#   '2',
#   '',
#   '',
#   '319'],
#  ['25',
#   'Austria',
#   '4,902,914',
#   '',
#   '19,407 ',
#   '',
#   '4,817,884',
#   '',
#   '65,623',
#   '69',
#   '537,763',
#   '2,129',
#   '195,410,181',
#   '21,433,039',
#   '9,117,241 ',
#   'Europe',
#   '2',
#   '470',
#   '0',
#   '',
#   '',
#   '7,198'],
#  ['26',
#   'Malaysia',
#   '4,780,284',
#   '',
#   '36,210 ',
#   '',
#   '4,712,915',
#   '',
#   '31,159',
#   '72',
#   '143,722',
#   '1,089',
#   '63,715,065',
#   '1,915,629',
#   '33,260,647 ',
#   'Asia',
#   '7',
#   '919',
#   '1',
#   '',
#   '',
#   '937'],
#  ['27',
#   'DPRK',
#   '4,772,813',
#   '',
#   '74 ',
#   '',
#   '4,772,739',
#   '',
#   '0',
#   '',
#   '183,411',
#   '3',
#   '',
#   '',
#   '26,022,483 ',
#   'Asia',
#   '5',
#   '351,655',
#   '',
#   '',
#   '',
#   ''],
#  ['28',
#   'Greece',
#   '4,762,827',
#   '',
#   '32,552 ',
#   '',
#   '4,654,921',
#   '',
#   '75,354',
#   '115',
#   '461,814',
#   '3,156',
#   '91,707,649',
#   '8,892,168',
#   '10,313,306 ',
#   'Europe',
#   '2',
#   '317',
#   '0',
#   '',
#   '',
#   '7,306'],
#  ['29',
#   'Thailand',
#   '4,650,919',
#   '+2,240',
#   '32,306 ',
#   '+28',
#   '4,602,862',
#   '+1,917',
#   '15,751',
#   '1,496',
#   '66,273',
#   '460',
#   '17,270,775',
#   '246,101',
#   '70,177,704 ',
#   'Asia',
#   '15',
#   '2,172',
#   '4',
#   '32',
#   '0.4',
#   '224'],
#  ['30',
#   'Israel',
#   '4,632,109',
#   '',
#   '11,603 ',
#   '',
#   '4,608,563',
#   '',
#   '11,943',
#   '266',
#   '496,688',
#   '1,244',
#   '41,373,364',
#   '4,436,346',
#   '9,326,000 ',
#   'Asia',
#   '2',
#   '804',
#   '0',
#   '',
#   '',
#   '1,281'],
#  ['31',
#   'Chile',
#   '4,502,674',
#   '',
#   '60,445 ',
#   '',
#   '4,415,436',
#   '',
#   '26,793',
#   '157',
#   '231,260',
#   '3,104',
#   '43,916,886',
#   '2,255,598',
#   '19,470,178 ',
#   'South America',
#   '4',
#   '322',
#   '0',
#   '',
#   '',
#   '1,376'],
#  ['32',
#   'Belgium',
#   '4,482,315',
#   '',
#   '32,516 ',
#   '',
#   '4,389,947',
#   '',
#   '59,852',
#   '63',
#   '383,156',
#   '2,780',
#   '35,286,170',
#   '3,016,322',
#   '11,698,411 ',
#   'Europe',
#   '3',
#   '360',
#   '0',
#   '',
#   '',
#   '5,116'],
#  ['33',
#   'Canada',
#   '4,158,491',
#   '',
#   '43,797 ',
#   '',
#   '4,028,676',
#   '+4,085',
#   '86,018',
#   '261',
#   '108,136',
#   '1,139',
#   '64,259,009',
#   '1,670,975',
#   '38,456,006 ',
#   'North America',
#   '9',
#   '878',
#   '1',
#   '',
#   '',
#   '2,237'],
#  ['34',
#   'Peru',
#   '4,100,923',
#   '',
#   '215,685 ',
#   '',
#   '3,830,985',
#   '',
#   '54,253',
#   '224',
#   '120,748',
#   '6,351',
#   '34,282,331',
#   '1,009,409',
#   '33,962,777 ',
#   'South America',
#   '8',
#   '157',
#   '1',
#   '',
#   '',
#   '1,597'],
#  ['35',
#   'Czechia',
#   '4,038,511',
#   '',
#   '40,805 ',
#   '',
#   '3,985,087',
#   '',
#   '12,619',
#   '28',
#   '375,612',
#   '3,795',
#   '55,955,186',
#   '5,204,250',
#   '10,751,826 ',
#   'Europe',
#   '3',
#   '263',
#   '0',
#   '',
#   '',
#   '1,174'],
#  ['36',
#   'Switzerland',
#   '4,025,870',
#   '',
#   '14,148 ',
#   '',
#   '3,937,093',
#   '',
#   '74,629',
#   '46',
#   '457,946',
#   '1,609',
#   '22,103,405',
#   '2,514,280',
#   '8,791,148 ',
#   'Europe',
#   '2',
#   '621',
#   '0',
#   '',
#   '',
#   '8,489'],
#  ['37',
#   'South Africa',
#   '4,011,657',
#   '',
#   '102,084 ',
#   '',
#   '3,902,822',
#   '',
#   '6,751',
#   '192',
#   '65,849',
#   '1,676',
#   '26,168,861',
#   '429,547',
#   '60,921,927 ',
#   'Africa',
#   '15',
#   '597',
#   '2',
#   '',
#   '',
#   '111'],
#  ['38',
#   'Philippines',
#   '3,878,734',
#   '',
#   '61,773 ',
#   '',
#   '3,790,793',
#   '',
#   '26,168',
#   '655',
#   '34,408',
#   '548',
#   '32,206,771',
#   '285,704',
#   '112,727,689 ',
#   'Asia',
#   '29',
#   '1,825',
#   '4',
#   '',
#   '',
#   '232'],
#  ['39',
#   'Romania',
#   '3,216,257',
#   '',
#   '66,673 ',
#   '',
#   '3,092,953',
#   '',
#   '56,631',
#   '219',
#   '169,624',
#   '3,516',
#   '24,643,997',
#   '1,299,714',
#   '18,961,090 ',
#   'Europe',
#   '6',
#   '284',
#   '1',
#   '',
#   '',
#   '2,987'],
#  ['40',
#   'Denmark',
#   '3,091,394',
#   '',
#   '6,920 ',
#   '',
#   '3,074,011',
#   '',
#   '10,463',
#   '6',
#   '529,693',
#   '1,186',
#   '128,191,650',
#   '21,964,940',
#   '5,836,194 ',
#   'Europe',
#   '2',
#   '843',
#   '0',
#   '',
#   '',
#   '1,793'],
#  ['41',
#   'Sweden',
#   '2,564,423',
#   '',
#   '19,779 ',
#   '',
#   '2,522,768',
#   '+292',
#   '21,876',
#   '17',
#   '250,552',
#   '1,932',
#   '18,844,252',
#   '1,841,140',
#   '10,235,099 ',
#   'Europe',
#   '4',
#   '517',
#   '1',
#   '',
#   '',
#   '2,137'],
#  ['42',
#   'Iraq',
#   '2,457,871',
#   '',
#   '25,346 ',
#   '',
#   '2,429,962',
#   '',
#   '2,563',
#   '21',
#   '58,285',
#   '601',
#   '19,212,734',
#   '455,602',
#   '42,169,962 ',
#   'Asia',
#   '17',
#   '1,664',
#   '2',
#   '',
#   '',
#   '61'],
#  ['43',
#   'Serbia',
#   '2,279,485',
#   '',
#   '16,672  ',
#   '',
#   '2,181,112',
#   '',
#   '81,701',
#   '25',
#   '263,174',
#   '1,925',
#   '10,663,811',
#   '1,231,174',
#   '8,661,501 ',
#   'Europe',
#   '4',
#   '520',
#   '1',
#   '',
#   '',
#   '9,433'],
#  ['44',
#   'Hungary',
#   '2,036,390',
#   '',
#   '47,191 ',
#   '',
#   '1,945,910',
#   '',
#   '43,289',
#   '27',
#   '211,959',
#   '4,912',
#   '11,394,556',
#   '1,186,011',
#   '9,607,466 ',
#   'Europe',
#   '5',
#   '204',
#   '1',
#   '',
#   '',
#   '4,506'],
#  ['45',
#   'Bangladesh',
#   '2,011,732',
#   '',
#   '29,323 ',
#   '',
#   '1,956,201',
#   '',
#   '26,208',
#   '1,331',
#   '11,958',
#   '174',
#   '14,747,609',
#   '87,664',
#   '168,228,948 ',
#   'Asia',
#   '84',
#   '5,737',
#   '11',
#   '',
#   '',
#   '156'],
#  ['46',
#   'Singapore',
#   '1,837,090',
#   '',
#   '1,592 ',
#   '',
#   '1,759,287',
#   '',
#   '76,211',
#   '10',
#   '308,776',
#   '268',
#   '24,342,902',
#   '4,091,524',
#   '5,949,593 ',
#   'Asia',
#   '3',
#   '3,737',
#   '0',
#   '',
#   '',
#   '12,809'],
#  ['47',
#   'Slovakia',
#   '1,833,873',
#   '',
#   '20,349 ',
#   '',
#   '1,808,150',
#   '',
#   '5,374',
#   '39',
#   '335,546',
#   '3,723',
#   '7,266,881',
#   '1,329,629',
#   '5,465,345 ',
#   'Europe',
#   '3',
#   '269',
#   '1',
#   '',
#   '',
#   '983'],
#  ['48',
#   'New Zealand',
#   '1,740,840',
#   '+2,348',
#   '2,742 ',
#   '+17',
#   '1,723,232',
#   '+3,271',
#   '14,866',
#   '',
#   '348,022',
#   '548',
#   '7,483,250',
#   '1,496,022',
#   '5,002,100 ',
#   'Australia/Oceania',
#   '3',
#   '1,824',
#   '1',
#   '469',
#   '3',
#   '2,972'],
#  ['49',
#   'Georgia',
#   '1,735,682',
#   '',
#   '16,889 ',
#   '',
#   '1,637,293',
#   '',
#   '81,500',
#   '',
#   '436,907',
#   '4,251',
#   '16,920,079',
#   '4,259,133',
#   '3,972,658 ',
#   'Asia',
#   '2',
#   '235',
#   '0',
#   '',
#   '',
#   '20,515'],
#  ['50',
#   'Jordan',
#   '1,735,495',
#   '',
#   '14,110 ',
#   '',
#   '1,718,032',
#   '',
#   '3,353',
#   '59',
#   '166,528',
#   '1,354',
#   '17,128,152',
#   '1,643,517',
#   '10,421,646 ',
#   'Asia',
#   '6',
#   '739',
#   '1',
#   '',
#   '',
#   '322'],
#  ['51',
#   'Ireland',
#   '1,655,338',
#   '',
#   '7,780 ',
#   '',
#   '1,638,645',
#   '',
#   '8,913',
#   '14',
#   '327,350',
#   '1,539',
#   '12,632,936',
#   '2,498,218',
#   '5,056,778 ',
#   'Europe',
#   '3',
#   '650',
#   '0',
#   '',
#   '',
#   '1,763'],
#  ['52',
#   'Pakistan',
#   '1,568,849',
#   '',
#   '30,575 ',
#   '',
#   '1,528,907',
#   '',
#   '9,367',
#   '111',
#   '6,817',
#   '133',
#   '30,095,965',
#   '130,769',
#   '230,146,526 ',
#   'Asia',
#   '147',
#   '7,527',
#   '8',
#   '',
#   '',
#   '41'],
#  ['53',
#   'Hong Kong',
#   '1,531,308',
#   '',
#   '9,681 ',
#   '',
#   '1,316,442',
#   '',
#   '205,185',
#   '13',
#   '200,743',
#   '1,269',
#   '54,352,132',
#   '7,125,172',
#   '7,628,185 ',
#   'Asia',
#   '5',
#   '788',
#   '0',
#   '',
#   '',
#   '26,898'],
#  ['54',
#   'Norway',
#   '1,460,011',
#   '',
#   '3,980 ',
#   '',
#   '1,454,112',
#   '',
#   '1,919',
#   '20',
#   '264,846',
#   '722',
#   '11,002,430',
#   '1,995,839',
#   '5,512,683 ',
#   'Europe',
#   '4',
#   '1,385',
#   '1',
#   '',
#   '',
#   '348'],
#  ['55',
#   'Kazakhstan',
#   '1,387,576',
#   '',
#   '13,684 ',
#   '',
#   '1,355,226',
#   '',
#   '18,666',
#   '24',
#   '72,040',
#   '710',
#   '11,575,012',
#   '600,948',
#   '19,261,244 ',
#   'Asia',
#   '14',
#   '1,408',
#   '2',
#   '',
#   '',
#   '969'],
#  ['56',
#   'Morocco',
#   '1,264,388',
#   '',
#   '16,273 ',
#   '',
#   '1,247,708',
#   '',
#   '407',
#   '293',
#   '33,401',
#   '430',
#   '12,448,105',
#   '328,842',
#   '37,854,399 ',
#   'Africa',
#   '30',
#   '2,326',
#   '3',
#   '',
#   '',
#   '11'],
#  ['57',
#   'Finland',
#   '1,258,798',
#   '',
#   '5,577 ',
#   '',
#   '1,224,052',
#   '+2,398',
#   '29,169',
#   '21',
#   '226,432',
#   '1,003',
#   '11,362,325',
#   '2,043,848',
#   '5,559,282 ',
#   'Europe',
#   '4',
#   '997',
#   '0',
#   '',
#   '',
#   '5,247'],
#  ['58',
#   'Bulgaria',
#   '1,242,133',
#   '',
#   '37,600 ',
#   '',
#   '1,191,783',
#   '',
#   '12,750',
#   '50',
#   '181,712',
#   '5,501',
#   '10,430,103',
#   '1,525,825',
#   '6,835,714 ',
#   'Europe',
#   '6',
#   '182',
#   '1',
#   '',
#   '',
#   '1,865'],
#  ['59',
#   'Lithuania',
#   '1,217,300',
#   '',
#   '9,286 ',
#   '',
#   '1,186,801',
#   '',
#   '21,213',
#   '6',
#   '461,017',
#   '3,517',
#   '10,114,206',
#   '3,830,464',
#   '2,640,465 ',
#   'Europe',
#   '2',
#   '284',
#   '0',
#   '',
#   '',
#   '8,034'],
#  ['60',
#   'Croatia',
#   '1,212,547',
#   '',
#   '16,690 ',
#   '',
#   '1,191,028',
#   '',
#   '4,829',
#   '23',
#   '299,343',
#   '4,120',
#   '5,135,085',
#   '1,267,703',
#   '4,050,699 ',
#   'Europe',
#   '3',
#   '243',
#   '1',
#   '',
#   '',
#   '1,192'],
#  ['61',
#   'Lebanon',
#   '1,208,681',
#   '',
#   '10,622 ',
#   '',
#   '1,087,587',
#   '',
#   '110,472',
#   '186',
#   '178,811',
#   '1,571',
#   '4,795,578',
#   '709,452',
#   '6,759,556 ',
#   'Asia',
#   '6',
#   '636',
#   '1',
#   '',
#   '',
#   '16,343'],
#  ['62',
#   'Tunisia',
#   '1,143,788',
#   '',
#   '29,234 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '99',
#   '94,642',
#   '2,419',
#   '4,917,212',
#   '406,872',
#   '12,085,405 ',
#   'Africa',
#   '11',
#   '413',
#   '2',
#   '',
#   '',
#   '1,375'],
#  ['63',
#   'Slovenia',
#   '1,125,145',
#   '',
#   '6,782 ',
#   '',
#   '1,097,916',
#   '',
#   '20,447',
#   '16',
#   '541,051',
#   '3,261',
#   '2,721,383',
#   '1,308,638',
#   '2,079,554 ',
#   'Europe',
#   '2',
#   '307',
#   '1',
#   '',
#   '',
#   '9,832'],
#  ['64',
#   'Cuba',
#   '1,110,497',
#   '',
#   '8,530 ',
#   '',
#   '1,101,687',
#   '',
#   '280',
#   '23',
#   '98,172',
#   '754',
#   '14,064,773',
#   '1,243,382',
#   '11,311,709 ',
#   'North America',
#   '10',
#   '1,326',
#   '1',
#   '',
#   '',
#   '25'],
#  ['65',
#   'Bolivia',
#   '1,100,820',
#   '',
#   '22,196 ',
#   '',
#   '1,027,835',
#   '',
#   '50,789',
#   '220',
#   '91,609',
#   '1,847',
#   '2,705,422',
#   '225,141',
#   '12,016,549 ',
#   'South America',
#   '11',
#   '541',
#   '4',
#   '',
#   '',
#   '4,227'],
#  ['66',
#   'Guatemala',
#   '1,100,437',
#   '',
#   '19,472 ',
#   '',
#   '1,072,428',
#   '',
#   '8,537',
#   '5',
#   '59,066',
#   '1,045',
#   '5,642,668',
#   '302,871',
#   '18,630,601 ',
#   'North America',
#   '17',
#   '957',
#   '3',
#   '',
#   '',
#   '458'],
#  ['67',
#   'Costa Rica',
#   '1,049,554',
#   '',
#   '8,836 ',
#   '',
#   '860,711',
#   '',
#   '180,007',
#   '52',
#   '202,052',
#   '1,701',
#   '4,659,757',
#   '897,062',
#   '5,194,466 ',
#   'North America',
#   '5',
#   '588',
#   '1',
#   '',
#   '',
#   '34,654'],
#  ['68',
#   'UAE',
#   '1,014,899',
#   '',
#   '2,341 ',
#   '',
#   '993,740',
#   '',
#   '18,818',
#   '',
#   '100,008',
#   '231',
#   '183,972,385',
#   '18,128,566',
#   '10,148,204 ',
#   'Asia',
#   '10',
#   '4,335',
#   '0',
#   '',
#   '',
#   '1,854'],
#  ['69',
#   'Nepal',
#   '997,122',
#   '',
#   '12,000 ',
#   '',
#   '981,976',
#   '',
#   '3,146',
#   '',
#   '32,944',
#   '396',
#   '5,887,718',
#   '194,523',
#   '30,267,487 ',
#   'Asia',
#   '30',
#   '2,522',
#   '5',
#   '',
#   '',
#   '104'],
#  ['70',
#   'Ecuador',
#   '995,147',
#   '',
#   '35,832 ',
#   '',
#   '947,709',
#   '+61',
#   '11,606',
#   '759',
#   '54,615',
#   '1,967',
#   '3,082,403',
#   '169,167',
#   '18,221,063 ',
#   'South America',
#   '18',
#   '509',
#   '6',
#   '',
#   '',
#   '637'],
#  ['71',
#   'Belarus',
#   '994,037',
#   '',
#   '7,118 ',
#   '',
#   '985,592',
#   '',
#   '1,327',
#   '',
#   '105,271',
#   '754',
#   '13,646,641',
#   '1,445,217',
#   '9,442,621 ',
#   'Europe',
#   '9',
#   '1,327',
#   '1',
#   '',
#   '',
#   '141'],
#  ['72',
#   'Uruguay',
#   '979,160',
#   '',
#   '7,445 ',
#   '',
#   '970,116',
#   '',
#   '1,599',
#   '18',
#   '279,784',
#   '2,127',
#   '6,114,822',
#   '1,747,245',
#   '3,499,694 ',
#   'South America',
#   '4',
#   '470',
#   '1',
#   '',
#   '',
#   '457'],
#  ['73',
#   'Mongolia',
#   '978,960',
#   '',
#   '2,179 ',
#   '',
#   '968,355',
#   '',
#   '8,426',
#   '192',
#   '288,592',
#   '642',
#   '4,030,048',
#   '1,188,037',
#   '3,392,192 ',
#   'Asia',
#   '3',
#   '1,557',
#   '1',
#   '',
#   '',
#   '2,484'],
#  ['74',
#   'Panama',
#   '978,181',
#   '',
#   '8,470 ',
#   '',
#   '962,280',
#   '',
#   '7,431',
#   '16',
#   '219,259',
#   '1,899',
#   '6,940,020',
#   '1,555,601',
#   '4,461,310 ',
#   'North America',
#   '5',
#   '527',
#   '1',
#   '',
#   '',
#   '1,666'],
#  ['75',
#   'Latvia',
#   '897,957',
#   '',
#   '5,944 ',
#   '',
#   '879,297',
#   '',
#   '12,716',
#   '6',
#   '487,685',
#   '3,228',
#   '7,530,042',
#   '4,089,600',
#   '1,841,266 ',
#   'Europe',
#   '2',
#   '310',
#   '0',
#   '',
#   '',
#   '6,906'],
#  ['76',
#   'Saudi Arabia',
#   '813,376',
#   '',
#   '9,293 ',
#   '',
#   '800,553',
#   '',
#   '3,530',
#   '42',
#   '22,604',
#   '258',
#   '44,110,709',
#   '1,225,855',
#   '35,983,617 ',
#   'Asia',
#   '44',
#   '3,872',
#   '1',
#   '',
#   '',
#   '98'],
#  ['77',
#   'Azerbaijan',
#   '812,248',
#   '',
#   '9,805 ',
#   '',
#   '798,867',
#   '',
#   '3,576',
#   '',
#   '78,582',
#   '949',
#   '7,147,186',
#   '691,463',
#   '10,336,323 ',
#   'Asia',
#   '13',
#   '1,054',
#   '1',
#   '',
#   '',
#   '346'],
#  ['78',
#   'Paraguay',
#   '715,162',
#   '',
#   '19,478 ',
#   '',
#   '693,283',
#   '',
#   '2,401',
#   '7',
#   '97,679',
#   '2,660',
#   '2,657,506',
#   '362,970',
#   '7,321,554 ',
#   'South America',
#   '10',
#   '376',
#   '3',
#   '',
#   '',
#   '328'],
#  ['79',
#   'Bahrain',
#   '671,484',
#   '',
#   '1,515 ',
#   '',
#   '668,414',
#   '',
#   '1,555',
#   '1',
#   '367,089',
#   '828',
#   '10,274,373',
#   '5,616,833',
#   '1,829,211 ',
#   'Asia',
#   '3',
#   '1,207',
#   '0',
#   '',
#   '',
#   '850'],
#  ['80',
#   'Sri Lanka',
#   '669,893',
#   '',
#   '16,695 ',
#   '',
#   '652,275',
#   '',
#   '923',
#   '',
#   '31,004',
#   '773',
#   '6,486,117',
#   '300,187',
#   '21,606,894 ',
#   'Asia',
#   '32',
#   '1,294',
#   '3',
#   '',
#   '',
#   '43'],
#  ['81',
#   'Kuwait',
#   '657,395',
#   '',
#   '2,563 ',
#   '',
#   '654,470',
#   '',
#   '362',
#   '3',
#   '149,176',
#   '582',
#   '8,340,400',
#   '1,892,607',
#   '4,406,832 ',
#   'Asia',
#   '7',
#   '1,719',
#   '1',
#   '',
#   '',
#   '82'],
#  ['82',
#   'Dominican Republic',
#   '638,500',
#   '',
#   '4,384 ',
#   '',
#   '632,911',
#   '',
#   '1,205',
#   '19',
#   '57,613',
#   '396',
#   '3,631,917',
#   '327,714',
#   '11,082,585 ',
#   'North America',
#   '17',
#   '2,528',
#   '3',
#   '',
#   '',
#   '109'],
#  ['83',
#   'Palestine',
#   '619,519',
#   '',
#   '5,396 ',
#   '',
#   '600,498',
#   '',
#   '13,625',
#   '17',
#   '115,640',
#   '1,007',
#   '3,078,533',
#   '574,644',
#   '5,357,288 ',
#   'Asia',
#   '9',
#   '993',
#   '2',
#   '',
#   '',
#   '2,543'],
#  ['84',
#   'Myanmar',
#   '615,117',
#   '',
#   '19,437 ',
#   '',
#   '593,567',
#   '',
#   '2,113',
#   '',
#   '11,144',
#   '352',
#   '8,736,103',
#   '158,273',
#   '55,196,589 ',
#   'Asia',
#   '90',
#   '2,840',
#   '6',
#   '',
#   '',
#   '38'],
#  ['85',
#   'Estonia',
#   '597,759',
#   '',
#   '2,651 ',
#   '',
#   '524,990',
#   '',
#   '70,118',
#   '4',
#   '449,964',
#   '1,996',
#   '3,504,375',
#   '2,637,925',
#   '1,328,459 ',
#   'Europe',
#   '2',
#   '501',
#   '0',
#   '',
#   '',
#   '52,781'],
#  ['86',
#   'Cyprus',
#   '574,124',
#   '',
#   '1,152 ',
#   '',
#   '569,294',
#   '+516',
#   '3,678',
#   '60',
#   '468,169',
#   '939',
#   '9,572,310',
#   '7,805,732',
#   '1,226,318 ',
#   'Asia',
#   '2',
#   '1,065',
#   '0',
#   '',
#   '',
#   '2,999'],
#  ['87',
#   'Moldova',
#   '569,088',
#   '',
#   '11,725 ',
#   '',
#   '504,142',
#   '',
#   '53,221',
#   '49',
#   '141,785',
#   '2,921',
#   '3,216,305',
#   '801,322',
#   '4,013,749 ',
#   'Europe',
#   '7',
#   '342',
#   '1',
#   '',
#   '',
#   '13,260'],
#  ['88',
#   'Venezuela',
#   '542,281',
#   '',
#   '5,796 ',
#   '',
#   '534,739',
#   '',
#   '1,746',
#   '36',
#   '19,187',
#   '205',
#   '3,359,014',
#   '118,852',
#   '28,262,237 ',
#   'South America',
#   '52',
#   '4,876',
#   '8',
#   '',
#   '',
#   '62'],
#  ['89',
#   'Egypt',
#   '515,645',
#   '',
#   '24,613 ',
#   '',
#   '442,182',
#   '',
#   '48,850',
#   '122',
#   '4,842',
#   '231',
#   '3,693,367',
#   '34,680',
#   '106,498,790 ',
#   'Africa',
#   '207',
#   '4,327',
#   '29',
#   '',
#   '',
#   '459'],
#  ['90',
#   'Libya',
#   '506,775',
#   '',
#   '6,437 ',
#   '',
#   '500,104',
#   '',
#   '234',
#   '101',
#   '71,650',
#   '910',
#   '2,479,485',
#   '350,562',
#   '7,072,877 ',
#   'Africa',
#   '14',
#   '1,099',
#   '3',
#   '',
#   '',
#   '33'],
#  ['91',
#   'Ethiopia',
#   '493,180',
#   '',
#   '7,572 ',
#   '',
#   '471,620',
#   '',
#   '13,988',
#   '13',
#   '4,072',
#   '63',
#   '5,202,940',
#   '42,961',
#   '121,107,941 ',
#   'Africa',
#   '246',
#   '15,994',
#   '23',
#   '',
#   '',
#   '116'],
#  ['92',
#   'Réunion',
#   '456,141',
#   '',
#   '861 ',
#   '',
#   '418,572',
#   '',
#   '36,708',
#   '10',
#   '501,753',
#   '947',
#   '1,603,660',
#   '1,764,020',
#   '909,094 ',
#   'Africa',
#   '2',
#   '1,056',
#   '1',
#   '',
#   '',
#   '40,379'],
#  ['93',
#   'Honduras',
#   '453,443',
#   '',
#   '10,972 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '105',
#   '44,262',
#   '1,071',
#   '1,499,738',
#   '146,395',
#   '10,244,478 ',
#   'North America',
#   '23',
#   '934',
#   '7',
#   '',
#   '',
#   '30,253'],
#  ['94',
#   'Armenia',
#   '434,398',
#   '',
#   '8,655 ',
#   '',
#   '421,316',
#   '',
#   '4,427',
#   '',
#   '146,007',
#   '2,909',
#   '3,184,464',
#   '1,070,341',
#   '2,975,187 ',
#   'Asia',
#   '7',
#   '344',
#   '1',
#   '',
#   '',
#   '1,488'],
#  ['95',
#   'Qatar',
#   '428,791',
#   '',
#   '681 ',
#   '',
#   '423,840',
#   '',
#   '4,270',
#   '2',
#   '152,714',
#   '243',
#   '3,862,771',
#   '1,375,726',
#   '2,807,805 ',
#   'Asia',
#   '7',
#   '4,123',
#   '1',
#   '',
#   '',
#   '1,521'],
#  ['96',
#   'Oman',
#   '397,846',
#   '',
#   '4,260 ',
#   '',
#   '384,669',
#   '',
#   '8,917',
#   '2',
#   '73,855',
#   '791',
#   '25,000,000',
#   '4,640,926',
#   '5,386,856 ',
#   'Asia',
#   '14',
#   '1,265',
#   '0',
#   '',
#   '',
#   '1,655'],
#  ['97',
#   'Bosnia and Herzegovina',
#   '395,630',
#   '',
#   '16,049 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '122,227',
#   '4,958',
#   '1,843,046',
#   '569,398',
#   '3,236,833 ',
#   'Europe',
#   '8',
#   '202',
#   '2',
#   '',
#   '',
#   '57,885'],
#  ['98',
#   'North Macedonia',
#   '340,119',
#   '',
#   '9,481 ',
#   '',
#   '328,924',
#   '',
#   '1,714',
#   '',
#   '163,268',
#   '4,551',
#   '2,117,284',
#   '1,016,366',
#   '2,083,190 ',
#   'Europe',
#   '6',
#   '220',
#   '1',
#   '',
#   '',
#   '823'],
#  ['99',
#   'Kenya',
#   '338,170',
#   '',
#   '5,674 ',
#   '',
#   '332,370',
#   '',
#   '126',
#   '1',
#   '6,004',
#   '101',
#   '3,854,643',
#   '68,433',
#   '56,326,866 ',
#   'Africa',
#   '167',
#   '9,927',
#   '15',
#   '',
#   '',
#   '2'],
#  ['100',
#   'Zambia',
#   '332,822',
#   '',
#   '4,016 ',
#   '',
#   '328,412',
#   '',
#   '394',
#   '1',
#   '17,072',
#   '206',
#   '3,696,213',
#   '189,599',
#   '19,494,894 ',
#   'Africa',
#   '59',
#   '4,854',
#   '5',
#   '',
#   '',
#   '20'],
#  ['101',
#   'Albania',
#   '329,017',
#   '',
#   '3,581 ',
#   '',
#   '320,970',
#   '',
#   '4,466',
#   '',
#   '114,599',
#   '1,247',
#   '1,941,032',
#   '676,077',
#   '2,871,022 ',
#   'Europe',
#   '9',
#   '802',
#   '1',
#   '',
#   '',
#   '1,556'],
#  ['102',
#   'Botswana',
#   '325,864',
#   '',
#   '2,778 ',
#   '',
#   '322,955',
#   '',
#   '131',
#   '1',
#   '132,785',
#   '1,132',
#   '2,026,898',
#   '825,932',
#   '2,454,074 ',
#   'Africa',
#   '8',
#   '883',
#   '1',
#   '',
#   '',
#   '53'],
#  ['103',
#   'Luxembourg',
#   '284,931',
#   '',
#   '1,114 ',
#   '',
#   '275,850',
#   '',
#   '7,967',
#   '',
#   '439,742',
#   '1,719',
#   '4,381,286',
#   '6,761,766',
#   '647,950 ',
#   'Europe',
#   '2',
#   '582',
#   '0',
#   '',
#   '',
#   '12,296'],
#  ['104',
#   'Montenegro',
#   '275,338',
#   '',
#   '2,773 ',
#   '',
#   '269,815',
#   '',
#   '2,750',
#   '6',
#   '438,271',
#   '4,414',
#   '2,596,326',
#   '4,132,717',
#   '628,237 ',
#   'Europe',
#   '2',
#   '227',
#   '0',
#   '',
#   '',
#   '4,377'],
#  ['105',
#   'Algeria',
#   '270,272',
#   '',
#   '6,878 ',
#   '',
#   '181,907',
#   '',
#   '81,487',
#   '6',
#   '5,932',
#   '151',
#   '230,861',
#   '5,067',
#   '45,559,479 ',
#   'Africa',
#   '169',
#   '6,624',
#   '197',
#   '',
#   '',
#   '1,789'],
#  ['106',
#   'Nigeria',
#   '263,526',
#   '',
#   '3,148 ',
#   '',
#   '257,343',
#   '',
#   '3,035',
#   '11',
#   '1,213',
#   '14',
#   '5,441,162',
#   '25,056',
#   '217,163,611 ',
#   'Africa',
#   '824',
#   '68,985',
#   '40',
#   '',
#   '',
#   '14'],
#  ['107',
#   'Zimbabwe',
#   '256,708',
#   '',
#   '5,593 ',
#   '',
#   '250,965',
#   '',
#   '150',
#   '12',
#   '16,746',
#   '365',
#   '2,480,422',
#   '161,805',
#   '15,329,720 ',
#   'Africa',
#   '60',
#   '2,741',
#   '6',
#   '',
#   '',
#   '10'],
#  ['108',
#   'Uzbekistan',
#   '243,743',
#   '',
#   '1,637 ',
#   '',
#   '241,486',
#   '',
#   '620',
#   '23',
#   '7,062',
#   '47',
#   '1,377,915',
#   '39,921',
#   '34,515,705 ',
#   'Asia',
#   '142',
#   '21,085',
#   '25',
#   '',
#   '',
#   '18'],
#  ['109',
#   'Mozambique',
#   '230,076',
#   '',
#   '2,219 ',
#   '',
#   '227,709',
#   '',
#   '148',
#   '11',
#   '6,942',
#   '67',
#   '1,371,127',
#   '41,368',
#   '33,144,921 ',
#   'Africa',
#   '144',
#   '14,937',
#   '24',
#   '',
#   '',
#   '4'],
#  ['110',
#   'Brunei ',
#   '220,245',
#   '',
#   '225 ',
#   '',
#   '219,561',
#   '',
#   '459',
#   '3',
#   '493,252',
#   '504',
#   '717,784',
#   '1,607,521',
#   '446,516 ',
#   'Asia',
#   '2',
#   '1,985',
#   '1',
#   '',
#   '',
#   '1,028'],
#  ['111',
#   'Martinique',
#   '218,764',
#   '',
#   '1,035 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '8',
#   '583,934',
#   '2,763',
#   '828,928',
#   '2,212,611',
#   '374,638 ',
#   'North America',
#   '2',
#   '362',
#   '0',
#   '',
#   '',
#   '580,894'],
#  ['112',
#   'Laos',
#   '213,925',
#   '',
#   '757 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '28,511',
#   '101',
#   '1,233,207',
#   '164,355',
#   '7,503,335 ',
#   'Asia',
#   '35',
#   '9,912',
#   '6',
#   '',
#   '',
#   '27,389'],
#  ['113',
#   'Kyrgyzstan',
#   '205,716',
#   '',
#   '2,991 ',
#   '',
#   '196,406',
#   '',
#   '6,319',
#   '131',
#   '30,447',
#   '443',
#   '1,907,195',
#   '282,279',
#   '6,756,429 ',
#   'Asia',
#   '33',
#   '2,259',
#   '4',
#   '',
#   '',
#   '935'],
#  ['114',
#   'Iceland',
#   '204,268',
#   '',
#   '179 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '2',
#   '590,336',
#   '517',
#   '1,993,053',
#   '5,759,936',
#   '346,020 ',
#   'Europe',
#   '2',
#   '1,933',
#   '0',
#   '',
#   '',
#   '371,088'],
#  ['115',
#   'Afghanistan',
#   '192,906',
#   '',
#   '7,777 ',
#   '',
#   '171,519',
#   '',
#   '13,610',
#   '1,124',
#   '4,726',
#   '191',
#   '1,066,354',
#   '26,123',
#   '40,819,968 ',
#   'Asia',
#   '212',
#   '5,249',
#   '38',
#   '',
#   '',
#   '333'],
#  ['116',
#   'Guadeloupe',
#   '191,997',
#   '',
#   '986 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '19',
#   '479,666',
#   '2,463',
#   '938,039',
#   '2,343,504',
#   '400,272 ',
#   'North America',
#   '2',
#   '406',
#   '0',
#   '',
#   '',
#   '471,582'],
#  ['117',
#   'El Salvador',
#   '190,818',
#   '',
#   '4,222 ',
#   '',
#   '172,310',
#   '',
#   '14,286',
#   '8',
#   '29,102',
#   '644',
#   '2,456,913',
#   '374,712',
#   '6,556,795 ',
#   'North America',
#   '34',
#   '1,553',
#   '3',
#   '',
#   '',
#   '2,179'],
#  ['118',
#   'Maldives',
#   '184,856',
#   '',
#   '308 ',
#   '',
#   '163,687',
#   '',
#   '20,861',
#   '25',
#   '329,462',
#   '549',
#   '2,213,831',
#   '3,945,625',
#   '561,085 ',
#   'Asia',
#   '3',
#   '1,822',
#   '0',
#   '',
#   '',
#   '37,180'],
#  ['119',
#   'Trinidad and Tobago',
#   '178,964',
#   '',
#   '4,139 ',
#   '',
#   '168,956',
#   '',
#   '5,869',
#   '18',
#   '126,991',
#   '2,937',
#   '818,286',
#   '580,649',
#   '1,409,262 ',
#   'North America',
#   '8',
#   '340',
#   '2',
#   '',
#   '',
#   '4,165'],
#  ['120',
#   'Uganda',
#   '169,396',
#   '',
#   '3,628 ',
#   '',
#   '100,431',
#   '',
#   '65,337',
#   '3',
#   '3,467',
#   '74',
#   '3,012,408',
#   '61,656',
#   '48,858,140 ',
#   'Africa',
#   '288',
#   '13,467',
#   '16',
#   '',
#   '',
#   '1,337'],
#  ['121',
#   'Namibia',
#   '169,253',
#   '',
#   '4,065 ',
#   '',
#   '164,813',
#   '',
#   '375',
#   '',
#   '64,106',
#   '1,540',
#   '1,062,663',
#   '402,496',
#   '2,640,186 ',
#   'Africa',
#   '16',
#   '649',
#   '2',
#   '',
#   '',
#   '142'],
#  ['122',
#   'Ghana',
#   '168,580',
#   '',
#   '1,459 ',
#   '',
#   '167,080',
#   '',
#   '41',
#   '2',
#   '5,191',
#   '45',
#   '2,496,486',
#   '76,880',
#   '32,472,398 ',
#   'Africa',
#   '193',
#   '22,257',
#   '13',
#   '',
#   '',
#   '1'],
#  ['123',
#   'Jamaica',
#   '149,763',
#   '',
#   '3,254 ',
#   '',
#   '96,514',
#   '',
#   '49,995',
#   '',
#   '50,104',
#   '1,089',
#   '1,168,888',
#   '391,058',
#   '2,989,043 ',
#   'North America',
#   '20',
#   '919',
#   '3',
#   '',
#   '',
#   '16,726'],
#  ['124',
#   'Cambodia',
#   '137,596',
#   '',
#   '3,056 ',
#   '',
#   '134,394',
#   '',
#   '146',
#   '',
#   '7,991',
#   '177',
#   '3,046,245',
#   '176,920',
#   '17,218,160 ',
#   'Asia',
#   '125',
#   '5,634',
#   '6',
#   '',
#   '',
#   '8'],
#  ['125',
#   'Rwanda',
#   '132,427',
#   '',
#   '1,466 ',
#   '',
#   '130,901',
#   '',
#   '60',
#   '',
#   '9,705',
#   '107',
#   '5,749,152',
#   '421,338',
#   '13,644,984 ',
#   'Africa',
#   '103',
#   '9,308',
#   '2',
#   '',
#   '',
#   '4'],
#  ['126',
#   'Cameroon',
#   '121,652',
#   '',
#   '1,935 ',
#   '',
#   '118,616',
#   '',
#   '1,101',
#   '13',
#   '4,349',
#   '69',
#   '1,751,774',
#   '62,627',
#   '27,971,634 ',
#   'Africa',
#   '230',
#   '14,456',
#   '16',
#   '',
#   '',
#   '39'],
#  ['127',
#   'Malta',
#   '114,026',
#   '',
#   '801 ',
#   '',
#   '112,700',
#   '',
#   '525',
#   '4',
#   '256,770',
#   '1,804',
#   '2,043,292',
#   '4,601,190',
#   '444,079 ',
#   'Europe',
#   '4',
#   '554',
#   '0',
#   '',
#   '',
#   '1,182'],
#  ['128',
#   'Angola',
#   '102,636',
#   '',
#   '1,917 ',
#   '',
#   '100,437',
#   '',
#   '282',
#   '',
#   '2,926',
#   '55',
#   '1,499,795',
#   '42,763',
#   '35,072,375 ',
#   'Africa',
#   '342',
#   '18,295',
#   '23',
#   '',
#   '',
#   '8'],
#  ['129',
#   'Barbados',
#   '100,973',
#   '',
#   '541 ',
#   '',
#   '98,974',
#   '',
#   '1,458',
#   '',
#   '350,438',
#   '1,878',
#   '754,506',
#   '2,618,594',
#   '288,134 ',
#   'North America',
#   '3',
#   '533',
#   '0',
#   '',
#   '',
#   '5,060'],
#  ['130',
#   'French Guiana',
#   '93,586',
#   '',
#   '408 ',
#   '',
#   '11,254',
#   '',
#   '81,924',
#   '3',
#   '296,735',
#   '1,294',
#   '650,106',
#   '2,061,303',
#   '315,386 ',
#   'South America',
#   '3',
#   '773',
#   '0',
#   '',
#   '',
#   '259,758'],
#  ['131',
#   'DRC',
#   '92,634',
#   '',
#   '1,400 ',
#   '',
#   '83,504',
#   '',
#   '7,730',
#   '',
#   '971',
#   '15',
#   '846,704',
#   '8,872',
#   '95,436,820 ',
#   'Africa',
#   '1,030',
#   '68,169',
#   '113',
#   '',
#   '',
#   '81'],
#  ['132',
#   'Channel Islands',
#   '89,657',
#   '',
#   '198 ',
#   '',
#   '89,125',
#   '',
#   '334',
#   '',
#   '505,623',
#   '1,117',
#   '1,252,808',
#   '7,065,238',
#   '177,320 ',
#   'Europe',
#   '2',
#   '896',
#   '0',
#   '',
#   '',
#   '1,884'],
#  ['133',
#   'Senegal',
#   '88,068',
#   '',
#   '1,968 ',
#   '',
#   '85,950',
#   '',
#   '150',
#   '',
#   '4,977',
#   '111',
#   '1,146,543',
#   '64,791',
#   '17,695,997 ',
#   'Africa',
#   '201',
#   '8,992',
#   '15',
#   '',
#   '',
#   '8'],
#  ['134',
#   'Malawi',
#   '87,856',
#   '',
#   '2,676 ',
#   '',
#   '84,919',
#   '',
#   '261',
#   '67',
#   '4,350',
#   '132',
#   '610,123',
#   '30,209',
#   '20,196,558 ',
#   'Africa',
#   '230',
#   '7,547',
#   '33',
#   '',
#   '',
#   '13'],
#  ['135',
#   'Ivory Coast',
#   '86,695',
#   '',
#   '819 ',
#   '',
#   '85,802',
#   '',
#   '74',
#   '',
#   '3,120',
#   '29',
#   '1,608,697',
#   '57,892',
#   '27,787,676 ',
#   'Africa',
#   '321',
#   '33,929',
#   '17',
#   '',
#   '',
#   '3'],
#  ['136',
#   'Suriname',
#   '81,039',
#   '',
#   '1,383 ',
#   '',
#   '49,614',
#   '',
#   '30,042',
#   '',
#   '135,523',
#   '2,313',
#   '238,852',
#   '399,437',
#   '597,971 ',
#   'South America',
#   '7',
#   '432',
#   '3',
#   '',
#   '',
#   '50,240'],
#  ['137',
#   'French Polynesia',
#   '76,439',
#   '',
#   '649 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '268,762',
#   '2,282',
#   '',
#   '',
#   '284,411 ',
#   'Australia/Oceania',
#   '4',
#   '438',
#   '',
#   '',
#   '',
#   '148,693'],
#  ['138',
#   'New Caledonia',
#   '73,798',
#   '',
#   '314 ',
#   '',
#   '73,032',
#   '',
#   '452',
#   '9',
#   '253,237',
#   '1,077',
#   '98,964',
#   '339,594',
#   '291,419 ',
#   'Australia/Oceania',
#   '4',
#   '928',
#   '3',
#   '',
#   '',
#   '1,551'],
#  ['139',
#   'Eswatini',
#   '73,361',
#   '',
#   '1,422 ',
#   '',
#   '71,922',
#   '',
#   '17',
#   '11',
#   '61,852',
#   '1,199',
#   '1,043,657',
#   '879,923',
#   '1,186,078 ',
#   'Africa',
#   '16',
#   '834',
#   '1',
#   '',
#   '',
#   '14'],
#  ['140',
#   'Guyana',
#   '71,005',
#   '',
#   '1,278 ',
#   '',
#   '69,492',
#   '',
#   '235',
#   '',
#   '89,344',
#   '1,608',
#   '687,557',
#   '865,137',
#   '794,738 ',
#   'South America',
#   '11',
#   '622',
#   '1',
#   '',
#   '',
#   '296'],
#  ['141',
#   'Belize',
#   '68,238',
#   '',
#   '680 ',
#   '',
#   '67,346',
#   '',
#   '212',
#   '6',
#   '165,144',
#   '1,646',
#   '576,016',
#   '1,394,030',
#   '413,202 ',
#   'North America',
#   '6',
#   '608',
#   '1',
#   '',
#   '',
#   '513'],
#  ['142',
#   'Fiji',
#   '68,153',
#   '',
#   '878 ',
#   '',
#   '66,158',
#   '',
#   '1,117',
#   '',
#   '74,856',
#   '964',
#   '648,560',
#   '712,346',
#   '910,457 ',
#   'Australia/Oceania',
#   '13',
#   '1,037',
#   '1',
#   '',
#   '',
#   '1,227'],
#  ['143',
#   'Madagascar',
#   '66,626',
#   '',
#   '1,410 ',
#   '',
#   '65,084',
#   '',
#   '132',
#   '2',
#   '2,280',
#   '48',
#   '510,775',
#   '17,476',
#   '29,227,039 ',
#   'Africa',
#   '439',
#   '20,728',
#   '57',
#   '',
#   '',
#   '5'],
#  ['144',
#   'Sudan',
#   '63,228',
#   '',
#   '4,961 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '1,373',
#   '108',
#   '562,941',
#   '12,222',
#   '46,058,287 ',
#   'Africa',
#   '728',
#   '9,284',
#   '82',
#   '',
#   '',
#   '389'],
#  ['145',
#   'Mauritania',
#   '62,762',
#   '',
#   '992 ',
#   '',
#   '61,730',
#   '',
#   '40',
#   '',
#   '12,774',
#   '202',
#   '946,675',
#   '192,673',
#   '4,913,368 ',
#   'Africa',
#   '78',
#   '4,953',
#   '5',
#   '',
#   '',
#   '8'],
#  ['146',
#   'Cabo Verde',
#   '62,310',
#   '',
#   '410 ',
#   '',
#   '61,828',
#   '',
#   '72',
#   '23',
#   '109,505',
#   '721',
#   '401,622',
#   '705,820',
#   '569,015 ',
#   'Africa',
#   '9',
#   '1,388',
#   '1',
#   '',
#   '',
#   '127'],
#  ['147',
#   'Bhutan',
#   '61,076',
#   '',
#   '21 ',
#   '',
#   '60,961',
#   '',
#   '94',
#   '',
#   '77,318',
#   '27',
#   '2,303,734',
#   '2,916,352',
#   '789,937 ',
#   'Asia',
#   '13',
#   '37,616',
#   '0',
#   '',
#   '',
#   '119'],
#  ['148',
#   'Syria',
#   '57,026',
#   '',
#   '3,163 ',
#   '',
#   '53,383',
#   '',
#   '480',
#   '',
#   '3,096',
#   '172',
#   '146,269',
#   '7,942',
#   '18,417,954 ',
#   'Asia',
#   '323',
#   '5,823',
#   '126',
#   '',
#   '',
#   '26'],
#  ['149',
#   'Burundi',
#   '49,212',
#   '',
#   '38 ',
#   '',
#   '47,677',
#   '',
#   '1,497',
#   '',
#   '3,889',
#   '3',
#   '345,742',
#   '27,321',
#   '12,654,953 ',
#   'Africa',
#   '257',
#   '333,025',
#   '37',
#   '',
#   '',
#   '118'],
#  ['150',
#   'Gabon',
#   '48,649',
#   '',
#   '306 ',
#   '',
#   '48,067',
#   '',
#   '276',
#   '',
#   '20,799',
#   '131',
#   '1,614,329',
#   '690,164',
#   '2,339,050 ',
#   'Africa',
#   '48',
#   '7,644',
#   '1',
#   '',
#   '',
#   '118'],
#  ['151',
#   'Seychelles',
#   '46,081',
#   '',
#   '169  ',
#   '',
#   '45,777',
#   '',
#   '135',
#   '',
#   '462,382',
#   '1,696',
#   '',
#   '',
#   '99,660 ',
#   'Africa',
#   '2',
#   '590',
#   '',
#   '',
#   '',
#   '1,355'],
#  ['152',
#   'Andorra',
#   '46,027',
#   '',
#   '154 ',
#   '',
#   '45,791',
#   '',
#   '82',
#   '14',
#   '593,652',
#   '1,986',
#   '249,838',
#   '3,222,386',
#   '77,532 ',
#   'Europe',
#   '2',
#   '503',
#   '0',
#   '',
#   '',
#   '1,058'],
#  ['153',
#   'Curaçao',
#   '45,127',
#   '',
#   '282 ',
#   '',
#   '44,720',
#   '',
#   '125',
#   '3',
#   '272,605',
#   '1,704',
#   '496,693',
#   '3,000,441',
#   '165,540 ',
#   'North America',
#   '4',
#   '587',
#   '0',
#   '',
#   '',
#   '755'],
#  ['154',
#   'Papua New Guinea',
#   '44,880',
#   '',
#   '664 ',
#   '',
#   '43,982',
#   '',
#   '234',
#   '7',
#   '4,819',
#   '71',
#   '249,149',
#   '26,754',
#   '9,312,692 ',
#   'Australia/Oceania',
#   '208',
#   '14,025',
#   '37',
#   '',
#   '',
#   '25'],
#  ['155',
#   'Aruba',
#   '42,792',
#   '',
#   '226 ',
#   '',
#   '42,340',
#   '',
#   '226',
#   '2',
#   '397,164',
#   '2,098',
#   '177,885',
#   '1,650,997',
#   '107,744 ',
#   'North America',
#   '3',
#   '477',
#   '1',
#   '',
#   '',
#   '2,098'],
#  ['156',
#   'Mauritius',
#   '40,178',
#   '',
#   '1,022 ',
#   '',
#   '38,454',
#   '',
#   '702',
#   '',
#   '31,480',
#   '801',
#   '358,675',
#   '281,023',
#   '1,276,319 ',
#   'Africa',
#   '32',
#   '1,249',
#   '4',
#   '',
#   '',
#   '550'],
#  ['157',
#   'Mayotte',
#   '40,004',
#   '',
#   '187 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '139,378',
#   '652',
#   '176,919',
#   '616,404',
#   '287,018 ',
#   'Africa',
#   '7',
#   '1,535',
#   '2',
#   '',
#   '',
#   '128,400'],
#  ['158',
#   'Tanzania',
#   '38,712',
#   '',
#   '841 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '611',
#   '13',
#   '',
#   '',
#   '63,405,524 ',
#   'Africa',
#   '1,638',
#   '75,393',
#   '',
#   '',
#   '',
#   '594'],
#  ['159',
#   'Togo',
#   '38,465',
#   '',
#   '282 ',
#   '',
#   '38,032',
#   '',
#   '151',
#   '',
#   '4,423',
#   '32',
#   '784,495',
#   '90,199',
#   '8,697,374 ',
#   'Africa',
#   '226',
#   '30,842',
#   '11',
#   '',
#   '',
#   '17'],
#  ['160',
#   'Isle of Man',
#   '38,008',
#   '',
#   '116 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '441,933',
#   '1,349',
#   '150,753',
#   '1,752,860',
#   '86,004 ',
#   'Europe',
#   '2',
#   '741',
#   '1',
#   '',
#   '',
#   '129,041'],
#  ['161',
#   'Guinea',
#   '37,470',
#   '',
#   '447 ',
#   '',
#   '36,763',
#   '',
#   '260',
#   '8',
#   '2,695',
#   '32',
#   '660,107',
#   '47,485',
#   '13,901,428 ',
#   'Africa',
#   '371',
#   '31,099',
#   '21',
#   '',
#   '',
#   '19'],
#  ['162',
#   'Bahamas',
#   '37,059',
#   '',
#   '823 ',
#   '',
#   '35,849',
#   '',
#   '387',
#   '1',
#   '92,336',
#   '2,051',
#   '248,846',
#   '620,022',
#   '401,350 ',
#   'North America',
#   '11',
#   '488',
#   '2',
#   '',
#   '',
#   '964'],
#  ['163',
#   'Faeroe Islands',
#   '34,658',
#   '',
#   '28 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '5',
#   '703,530',
#   '568',
#   '778,000',
#   '15,792,786',
#   '49,263 ',
#   'Europe',
#   '1',
#   '1,759',
#   '0',
#   '',
#   '',
#   '546,800'],
#  ['164',
#   'Lesotho',
#   '34,206',
#   '',
#   '704 ',
#   '',
#   '25,740',
#   '',
#   '7,762',
#   '',
#   '15,699',
#   '323',
#   '431,221',
#   '197,909',
#   '2,178,882 ',
#   'Africa',
#   '64',
#   '3,095',
#   '5',
#   '',
#   '',
#   '3,562'],
#  ['165',
#   'Haiti',
#   '33,381',
#   '',
#   '841 ',
#   '',
#   '30,673',
#   '',
#   '1,867',
#   '',
#   '2,852',
#   '72',
#   '132,422',
#   '11,316',
#   '11,702,411 ',
#   'North America',
#   '351',
#   '13,915',
#   '88',
#   '',
#   '',
#   '160'],
#  ['166',
#   'Mali',
#   '31,365',
#   '',
#   '739 ',
#   '',
#   '30,461',
#   '',
#   '165',
#   '',
#   '1,458',
#   '34',
#   '739,184',
#   '34,366',
#   '21,509,432 ',
#   'Africa',
#   '686',
#   '29,106',
#   '29',
#   '',
#   '',
#   '8'],
#  ['167',
#   'Cayman Islands',
#   '30,057',
#   '',
#   '29 ',
#   '',
#   '8,553',
#   '',
#   '21,475',
#   '1',
#   '446,036',
#   '430',
#   '222,773',
#   '3,305,875',
#   '67,387 ',
#   'North America',
#   '2',
#   '2,324',
#   '0',
#   '',
#   '',
#   '318,682'],
#  ['168',
#   'Saint Lucia',
#   '28,775',
#   '',
#   '391 ',
#   '',
#   '28,260',
#   '',
#   '124',
#   '',
#   '155,174',
#   '2,109',
#   '209,716',
#   '1,130,929',
#   '185,437 ',
#   'North America',
#   '6',
#   '474',
#   '1',
#   '',
#   '',
#   '669'],
#  ['169',
#   'Benin',
#   '27,490',
#   '',
#   '163 ',
#   '',
#   '27,217',
#   '',
#   '110',
#   '5',
#   '2,146',
#   '13',
#   '604,310',
#   '47,181',
#   '12,808,358 ',
#   'Africa',
#   '466',
#   '78,579',
#   '21',
#   '',
#   '',
#   '9'],
#  ['170',
#   'Somalia',
#   '27,020',
#   '',
#   '1,350 ',
#   '',
#   '13,182',
#   '',
#   '12,488',
#   '',
#   '1,604',
#   '80',
#   '400,466',
#   '23,767',
#   '16,849,987 ',
#   'Africa',
#   '624',
#   '12,481',
#   '42',
#   '',
#   '',
#   '741'],
#  ['171',
#   'Congo',
#   '24,837',
#   '',
#   '386 ',
#   '',
#   '24,006',
#   '',
#   '445',
#   '',
#   '4,274',
#   '66',
#   '347,815',
#   '59,853',
#   '5,811,147 ',
#   'Africa',
#   '234',
#   '15,055',
#   '17',
#   '',
#   '',
#   '77'],
#  ['172',
#   'Timor-Leste',
#   '23,163',
#   '',
#   '138 ',
#   '',
#   '22,981',
#   '',
#   '44',
#   '',
#   '16,875',
#   '101',
#   '275,776',
#   '200,911',
#   '1,372,625 ',
#   'Asia',
#   '59',
#   '9,947',
#   '5',
#   '',
#   '',
#   '32'],
#  ['173',
#   'Solomon Islands',
#   '21,544',
#   '',
#   '153 ',
#   '',
#   '16,357',
#   '',
#   '5,034',
#   '1',
#   '29,789',
#   '212',
#   '5,117',
#   '7,075',
#   '723,229 ',
#   'Australia/Oceania',
#   '34',
#   '4,727',
#   '141',
#   '',
#   '',
#   '6,960'],
#  ['174',
#   'Burkina Faso',
#   '21,128',
#   '',
#   '387 ',
#   '',
#   '20,632',
#   '',
#   '109',
#   '',
#   '954',
#   '17',
#   '248,995',
#   '11,246',
#   '22,140,061 ',
#   'Africa',
#   '1,048',
#   '57,209',
#   '89',
#   '',
#   '',
#   '5'],
#  ['175',
#   'San Marino',
#   '20,365',
#   '',
#   '118 ',
#   '',
#   '20,146',
#   '',
#   '101',
#   '4',
#   '597,477',
#   '3,462',
#   '157,634',
#   '4,624,732',
#   '34,085 ',
#   'Europe',
#   '2',
#   '289',
#   '0',
#   '',
#   '',
#   '2,963'],
#  ['176',
#   'Gibraltar',
#   '20,049',
#   '',
#   '107 ',
#   '',
#   '16,579',
#   '',
#   '3,363',
#   '',
#   '595,474',
#   '3,178',
#   '534,283',
#   '15,868,692',
#   '33,669 ',
#   'Europe',
#   '2',
#   '315',
#   '0',
#   '',
#   '',
#   '99,884'],
#  ['177',
#   'Grenada',
#   '19,289',
#   '',
#   '236 ',
#   '',
#   '18,878',
#   '',
#   '175',
#   '4',
#   '169,726',
#   '2,077',
#   '177,423',
#   '1,561,163',
#   '113,648 ',
#   'North America',
#   '6',
#   '482',
#   '1',
#   '',
#   '',
#   '1,540'],
#  ['178',
#   'Liechtenstein',
#   '19,146',
#   '',
#   '86 ',
#   '',
#   '18,950',
#   '',
#   '110',
#   '1',
#   '499,062',
#   '2,242',
#   '102,174',
#   '2,663,278',
#   '38,364 ',
#   'Europe',
#   '2',
#   '446',
#   '0',
#   '',
#   '',
#   '2,867'],
#  ['179',
#   'Nicaragua',
#   '18,491',
#   '',
#   '225 ',
#   '',
#   '4,225',
#   '',
#   '14,041',
#   '',
#   '2,721',
#   '33',
#   '',
#   '',
#   '6,794,589 ',
#   'North America',
#   '367',
#   '30,198',
#   '',
#   '',
#   '',
#   '2,066'],
#  ['180',
#   'South Sudan',
#   '17,823',
#   '',
#   '138 ',
#   '',
#   '17,335',
#   '',
#   '350',
#   '1',
#   '1,553',
#   '12',
#   '410,280',
#   '35,748',
#   '11,476,849 ',
#   'Africa',
#   '644',
#   '83,166',
#   '28',
#   '',
#   '',
#   '30'],
#  ['181',
#   'Tajikistan',
#   '17,786',
#   '',
#   '125 ',
#   '',
#   '17,264',
#   '',
#   '397',
#   '',
#   '1,779',
#   '13',
#   '',
#   '',
#   '9,999,859 ',
#   'Asia',
#   '562',
#   '79,999',
#   '',
#   '',
#   '',
#   '40'],
#  ['182',
#   'Bermuda',
#   '17,785',
#   '',
#   '148 ',
#   '',
#   '17,516',
#   '',
#   '121',
#   '',
#   '287,867',
#   '2,396',
#   '983,456',
#   '15,918,164',
#   '61,782 ',
#   'North America',
#   '3',
#   '417',
#   '0',
#   '',
#   '',
#   '1,958'],
#  ['183',
#   'Equatorial Guinea',
#   '16,950',
#   '',
#   '183 ',
#   '',
#   '16,602',
#   '',
#   '165',
#   '5',
#   '11,282',
#   '122',
#   '365,697',
#   '243,400',
#   '1,502,450 ',
#   'Africa',
#   '89',
#   '8,210',
#   '4',
#   '',
#   '',
#   '110'],
#  ['184',
#   'Samoa',
#   '15,767',
#   '',
#   '29 ',
#   '',
#   '1,605',
#   '',
#   '14,133',
#   '4',
#   '78,342',
#   '144',
#   '187,397',
#   '931,128',
#   '201,258 ',
#   'Australia/Oceania',
#   '13',
#   '6,940',
#   '1',
#   '',
#   '',
#   '70,223'],
#  ['185',
#   'Djibouti',
#   '15,690',
#   '',
#   '189 ',
#   '',
#   '15,427',
#   '',
#   '74',
#   '',
#   '15,397',
#   '185',
#   '305,941',
#   '300,237',
#   '1,018,998 ',
#   'Africa',
#   '65',
#   '5,392',
#   '3',
#   '',
#   '',
#   '73'],
#  ['186',
#   'Tonga',
#   '15,235',
#   '',
#   '12 ',
#   '',
#   '14,317',
#   '',
#   '906',
#   '',
#   '140,701',
#   '111',
#   '535,009',
#   '4,941,023',
#   '108,279 ',
#   'Australia/Oceania',
#   '7',
#   '9,023',
#   '0',
#   '',
#   '',
#   '8,367'],
#  ['187',
#   'Marshall Islands',
#   '15,007',
#   '',
#   '17 ',
#   '',
#   '12,337',
#   '',
#   '2,653',
#   '22',
#   '249,900',
#   '283',
#   '',
#   '',
#   '60,052 ',
#   'Australia/Oceania',
#   '4',
#   '3,532',
#   '',
#   '',
#   '',
#   '44,178'],
#  ['188',
#   'CAR',
#   '14,862',
#   '',
#   '113 ',
#   '',
#   '14,520',
#   '',
#   '229',
#   '2',
#   '2,966',
#   '23',
#   '81,294',
#   '16,223',
#   '5,010,943 ',
#   'Africa',
#   '337',
#   '44,345',
#   '62',
#   '',
#   '',
#   '46'],
#  ['189',
#   'Dominica',
#   '14,852',
#   '',
#   '68 ',
#   '',
#   '14,554',
#   '',
#   '230',
#   '',
#   '205,217',
#   '940',
#   '210,195',
#   '2,904,369',
#   '72,372 ',
#   'North America',
#   '5',
#   '1,064',
#   '0',
#   '',
#   '',
#   '3,178'],
#  ['190',
#   'Monaco',
#   '14,375',
#   '',
#   '57 ',
#   '',
#   '14,268',
#   '',
#   '50',
#   '4',
#   '360,800',
#   '1,431',
#   '77,770',
#   '1,951,960',
#   '39,842 ',
#   'Europe',
#   '3',
#   '699',
#   '1',
#   '',
#   '',
#   '1,255'],
#  ['191',
#   'Gambia',
#   '12,311',
#   '',
#   '371 ',
#   '',
#   '11,788',
#   '',
#   '152',
#   '',
#   '4,803',
#   '145',
#   '155,686',
#   '60,740',
#   '2,563,166 ',
#   'Africa',
#   '208',
#   '6,909',
#   '16',
#   '',
#   '',
#   '59'],
#  ['192',
#   'Greenland',
#   '11,971',
#   '',
#   '21 ',
#   '',
#   '2,761',
#   '',
#   '9,189',
#   '4',
#   '210,084',
#   '369',
#   '164,926',
#   '2,894,353',
#   '56,982 ',
#   'North America',
#   '5',
#   '2,713',
#   '0',
#   '',
#   '',
#   '161,261'],
#  ['193',
#   'Saint Martin',
#   '11,941',
#   '',
#   '63 ',
#   '',
#   '1,399',
#   '',
#   '10,479',
#   '7',
#   '297,862',
#   '1,572',
#   '112,382',
#   '2,803,313',
#   '40,089 ',
#   'North America',
#   '3',
#   '636',
#   '0',
#   '',
#   '',
#   '261,393'],
#  ['194',
#   'Yemen',
#   '11,925',
#   '',
#   '2,155 ',
#   '',
#   '9,119',
#   '',
#   '651',
#   '23',
#   '382',
#   '69',
#   '329,592',
#   '10,549',
#   '31,243,301 ',
#   'Asia',
#   '2,620',
#   '14,498',
#   '95',
#   '',
#   '',
#   '21'],
#  ['195',
#   'Vanuatu',
#   '11,793',
#   '',
#   '14 ',
#   '',
#   '11,751',
#   '',
#   '28',
#   '',
#   '36,553',
#   '43',
#   '24,976',
#   '77,414',
#   '322,631 ',
#   'Australia/Oceania',
#   '27',
#   '23,045',
#   '13',
#   '',
#   '',
#   '87'],
#  ['196',
#   'Caribbean Netherlands',
#   '11,028',
#   '',
#   '35 ',
#   '',
#   '10,476',
#   '',
#   '517',
#   '',
#   '412,277',
#   '1,308',
#   '30,126',
#   '1,126,248',
#   '26,749 ',
#   'North America',
#   '2',
#   '764',
#   '1',
#   '',
#   '',
#   '19,328'],
#  ['197',
#   'Sint Maarten',
#   '10,836',
#   '',
#   '87 ',
#   '',
#   '10,741',
#   '',
#   '8',
#   '10',
#   '246,688',
#   '1,981',
#   '62,056',
#   '1,412,740',
#   '43,926 ',
#   'North America',
#   '4',
#   '505',
#   '1',
#   '',
#   '',
#   '182'],
#  ['198',
#   'Eritrea',
#   '10,154',
#   '',
#   '103 ',
#   '',
#   '10,046',
#   '',
#   '5',
#   '',
#   '2,780',
#   '28',
#   '23,693',
#   '6,487',
#   '3,652,315 ',
#   'Africa',
#   '360',
#   '35,459',
#   '154',
#   '',
#   '',
#   '1'],
#  ['199',
#   'Niger',
#   '9,329',
#   '',
#   '312 ',
#   '',
#   '8,863',
#   '',
#   '154',
#   '1',
#   '357',
#   '12',
#   '254,538',
#   '9,753',
#   '26,097,614 ',
#   'Africa',
#   '2,797',
#   '83,646',
#   '103',
#   '',
#   '',
#   '6'],
#  ['200',
#   'Antigua and Barbuda',
#   '8,974',
#   '',
#   '145 ',
#   '',
#   '8,794',
#   '',
#   '35',
#   '1',
#   '90,030',
#   '1,455',
#   '18,901',
#   '189,621',
#   '99,678 ',
#   'North America',
#   '11',
#   '687',
#   '5',
#   '',
#   '',
#   '351'],
#  ['201',
#   'Guinea-Bissau',
#   '8,491',
#   '',
#   '175 ',
#   '',
#   '8,300',
#   '',
#   '16',
#   '6',
#   '4,105',
#   '85',
#   '145,231',
#   '70,215',
#   '2,068,361 ',
#   'Africa',
#   '244',
#   '11,819',
#   '14',
#   '',
#   '',
#   '8'],
#  ['202',
#   'Comoros',
#   '8,450',
#   '',
#   '161 ',
#   '',
#   '8,270',
#   '',
#   '19',
#   '',
#   '9,290',
#   '177',
#   '',
#   '',
#   '909,569 ',
#   'Africa',
#   '108',
#   '5,649',
#   '',
#   '',
#   '',
#   '21'],
#  ['203',
#   'Liberia',
#   '7,835',
#   '',
#   '294 ',
#   '',
#   '7,260',
#   '',
#   '281',
#   '2',
#   '1,474',
#   '55',
#   '139,824',
#   '26,312',
#   '5,314,171 ',
#   'Africa',
#   '678',
#   '18,075',
#   '38',
#   '',
#   '',
#   '53'],
#  ['204',
#   'Sierra Leone',
#   '7,747',
#   '',
#   '126 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '930',
#   '15',
#   '259,958',
#   '31,219',
#   '8,326,986 ',
#   'Africa',
#   '1,075',
#   '66,087',
#   '32',
#   '',
#   '',
#   '331'],
#  ['205',
#   'Chad',
#   '7,538',
#   '',
#   '193 ',
#   '',
#   '4,874',
#   '',
#   '2,471',
#   '',
#   '432',
#   '11',
#   '191,341',
#   '10,970',
#   '17,442,907 ',
#   'Africa',
#   '2,314',
#   '90,378',
#   '91',
#   '',
#   '',
#   '142'],
#  ['206',
#   'Micronesia',
#   '7,326',
#   '',
#   '26 ',
#   '',
#   '144',
#   '',
#   '7,156',
#   '1',
#   '62,283',
#   '221',
#   '21,923',
#   '186,382',
#   '117,624 ',
#   'Australia/Oceania',
#   '16',
#   '4,524',
#   '5',
#   '',
#   '',
#   '60,838'],
#  ['207',
#   'British Virgin Islands',
#   '7,291',
#   '',
#   '64 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '237,763',
#   '2,087',
#   '107,243',
#   '3,497,244',
#   '30,665 ',
#   'North America',
#   '4',
#   '479',
#   '0',
#   '',
#   '',
#   '750'],
#  ['208',
#   'St. Vincent Grenadines',
#   '7,112',
#   '',
#   '115 ',
#   '',
#   '6,641',
#   '',
#   '356',
#   '',
#   '63,671',
#   '1,030',
#   '100,856',
#   '902,919',
#   '111,700 ',
#   'North America',
#   '16',
#   '971',
#   '1',
#   '',
#   '',
#   '3,187'],
#  ['209',
#   'Saint Kitts and Nevis',
#   '6,509',
#   '',
#   '46 ',
#   '',
#   '6,446',
#   '',
#   '17',
#   '',
#   '120,512',
#   '852',
#   '124,861',
#   '2,311,770',
#   '54,011 ',
#   'North America',
#   '8',
#   '1,174',
#   '0',
#   '',
#   '',
#   '315'],
#  ['210',
#   'Turks and Caicos',
#   '6,359',
#   '',
#   '36 ',
#   '',
#   '6,285',
#   '',
#   '38',
#   '4',
#   '159,585',
#   '903',
#   '549,718',
#   '13,795,719',
#   '39,847 ',
#   'North America',
#   '6',
#   '1,107',
#   '0',
#   '',
#   '',
#   '954'],
#  ['211',
#   'Cook Islands',
#   '6,265',
#   '',
#   '1 ',
#   '',
#   '6,176',
#   '',
#   '88',
#   '',
#   '355,986',
#   '57',
#   '19,690',
#   '1,118,814',
#   '17,599 ',
#   'Australia/Oceania',
#   '3',
#   '17,599',
#   '1',
#   '',
#   '',
#   '5,000'],
#  ['212',
#   'Sao Tome and Principe',
#   '6,153',
#   '',
#   '76 ',
#   '',
#   '6,060',
#   '',
#   '17',
#   '',
#   '26,994',
#   '333',
#   '29,036',
#   '127,384',
#   '227,940 ',
#   'Africa',
#   '37',
#   '2,999',
#   '8',
#   '',
#   '',
#   '75'],
#  ['213',
#   'Palau',
#   '5,348',
#   '',
#   '6 ',
#   '',
#   '5,265',
#   '',
#   '77',
#   '1',
#   '292,560',
#   '328',
#   '64,027',
#   '3,502,571',
#   '18,280 ',
#   'Australia/Oceania',
#   '3',
#   '3,047',
#   '0',
#   '',
#   '',
#   '4,212'],
#  ['214',
#   'St. Barth',
#   '5,263',
#   '',
#   '6 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '529,370',
#   '604',
#   '78,646',
#   '7,910,481',
#   '9,942 ',
#   'North America',
#   '2',
#   '1,657',
#   '0',
#   '',
#   '',
#   '482,297'],
#  ['215',
#   'Nauru',
#   '4,611',
#   '',
#   '1 ',
#   '',
#   '4,605',
#   '',
#   '5',
#   '',
#   '420,290',
#   '91',
#   '20,509',
#   '1,869,383',
#   '10,971 ',
#   'Australia/Oceania',
#   '2',
#   '10,971',
#   '1',
#   '',
#   '',
#   '456'],
#  ['216',
#   'Anguilla',
#   '3,837',
#   '',
#   '11 ',
#   '',
#   '3,789',
#   '',
#   '37',
#   '4',
#   '250,916',
#   '719',
#   '51,382',
#   '3,360,058',
#   '15,292 ',
#   'North America',
#   '4',
#   '1,390',
#   '0',
#   '',
#   '',
#   '2,420'],
#  ['217',
#   'Kiribati',
#   '3,430',
#   '',
#   '13 ',
#   '',
#   '2,703',
#   '',
#   '714',
#   '3',
#   '27,795',
#   '105',
#   '',
#   '',
#   '123,403 ',
#   'Australia/Oceania',
#   '36',
#   '9,493',
#   '',
#   '',
#   '',
#   '5,786'],
#  ['218',
#   'Saint Pierre Miquelon',
#   '3,131',
#   '',
#   '1 ',
#   '',
#   '2,449',
#   '',
#   '681',
#   '1',
#   '546,136',
#   '174',
#   '24,902',
#   '4,343,625',
#   '5,733 ',
#   'North America',
#   '2',
#   '5,733',
#   '0',
#   '',
#   '',
#   '118,786'],
#  ['219',
#   'Falkland Islands',
#   '1,886',
#   '',
#   ' ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '509,868',
#   '',
#   '8,632',
#   '2,333,604',
#   '3,699 ',
#   'South America',
#   '2',
#   '',
#   '0',
#   '',
#   '',
#   '476,345'],
#  ['220',
#   'Montserrat',
#   '1,145',
#   '',
#   '8 ',
#   '',
#   '1,106',
#   '',
#   '31',
#   '',
#   '229,046',
#   '1,600',
#   '16,169',
#   '3,234,447',
#   '4,999 ',
#   'North America',
#   '4',
#   '625',
#   '0',
#   '',
#   '',
#   '6,201'],
#  ['221',
#   'Macao',
#   '793',
#   '',
#   '6 ',
#   '',
#   '785',
#   '',
#   '2',
#   '',
#   '1,186',
#   '9',
#   '7,850',
#   '11,744',
#   '668,432 ',
#   'Asia',
#   '843',
#   '111,405',
#   '85',
#   '',
#   '',
#   '3'],
#  ['222',
#   'Wallis and Futuna',
#   '761',
#   '',
#   '7 ',
#   '',
#   '438',
#   '',
#   '316',
#   '',
#   '70,365',
#   '647',
#   '20,508',
#   '1,896,255',
#   '10,815 ',
#   'Australia/Oceania',
#   '14',
#   '1,545',
#   '1',
#   '',
#   '',
#   '29,219'],
#  ['223',
#   'Diamond Princess',
#   '712',
#   '',
#   '13 ',
#   '',
#   '699',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['224',
#   'Niue',
#   '70',
#   '',
#   ' ',
#   '',
#   '60',
#   '',
#   '10',
#   '',
#   '42,424',
#   '',
#   '',
#   '',
#   '1,650 ',
#   'Australia/Oceania',
#   '24',
#   '',
#   '',
#   '',
#   '',
#   '6,061'],
#  ['225',
#   'Vatican City',
#   '29',
#   '',
#   ' ',
#   '',
#   '29',
#   '',
#   '0',
#   '',
#   '36,025',
#   '',
#   '',
#   '',
#   '805 ',
#   'Europe',
#   '28',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['226',
#   'Western Sahara',
#   '10',
#   '',
#   '1 ',
#   '',
#   '9',
#   '',
#   '0',
#   '',
#   '16',
#   '2',
#   '',
#   '',
#   '629,027 ',
#   'Africa',
#   '62,903',
#   '629,027',
#   '',
#   '',
#   '',
#   ''],
#  ['227',
#   'MS Zaandam',
#   '9',
#   '',
#   '2 ',
#   '',
#   '7',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['228',
#   'Tuvalu',
#   '8',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '8',
#   '',
#   '661',
#   '',
#   '',
#   '',
#   '12,106 ',
#   'Australia/Oceania',
#   '1,513',
#   '',
#   '',
#   '',
#   '',
#   '661'],
#  ['229',
#   'Saint Helena',
#   '7',
#   '',
#   ' ',
#   '',
#   '2',
#   '',
#   '5',
#   '',
#   '1,145',
#   '',
#   '',
#   '',
#   '6,116 ',
#   'Africa',
#   '874',
#   '',
#   '',
#   '',
#   '',
#   '818'],
#  ['230',
#   'China',
#   '243,081',
#   '+392',
#   '5,226 ',
#   '',
#   '231,520',
#   '+540',
#   '6,335',
#   '31',
#   '169',
#   '4',
#   '160,000,000',
#   '111,163',
#   '1,439,323,776 ',
#   'Asia',
#   '5,921',
#   '275,416',
#   '9',
#   '0.3',
#   '',
#   '4']]

# %%
cleaned_data=list(map(lambda x: x[1:10] + [x[12],x[14]],whole_data))

# %%
column_names=["Country",
"Total cases",
"New cases",
"total deaths",
"new deaths",
"total recovered",
"new recovered",
"active cases",
"serious Cases",
"total test",
"population",]

# %%
import pandas as pd

# %%
df=pd.DataFrame(cleaned_data,columns = column_names)

# %%
df.to_csv('coviddata.csv',index=False)

# %%
df=pd.read_csv('coviddata.csv')

# %%
df.head(5)
# Out:
#    Country Total cases New cases total deaths  new deaths total recovered  \
# 0      USA  96,149,016       NaN   1,069,748          NaN      91,873,169
# 1    India  44,429,258       NaN     527,829          NaN      43,825,024
# 2   France  34,509,961       NaN     154,039          NaN      33,990,930
# 3   Brazil  34,414,011       NaN     683,914          NaN      33,457,359
# 4  Germany  32,095,854       NaN     147,223          NaN      31,204,400
#
#   new recovered active cases serious Cases     total test      population
# 0           NaN    3,206,099         4,029  1,100,355,942
# 1           NaN       76,405           698    885,528,970  1,409,273,386
# 2           NaN      364,992           869    271,490,188     65,584,999
# 3           NaN      272,738         8,318     63,776,166    215,818,679
# 4           NaN      744,231         1,406    122,332,384     84,361,727

# %%
df.tail(5)
# Out:
#             Country Total cases New cases total deaths  new deaths  \
# 225  Western Sahara          10       NaN           1          NaN
# 226      MS Zaandam           9       NaN           2          NaN
# 227          Tuvalu           8       NaN                      NaN
# 228    Saint Helena           7       NaN                      NaN
# 229           China     243,081      +392       5,226          NaN
#
#     total recovered new recovered active cases serious Cases   total test  \
# 225               9           NaN            0           NaN          NaN
# 226               7           NaN            0           NaN          NaN
# 227             NaN           NaN            8           NaN          NaN
# 228               2           NaN            5           NaN          NaN
# 229         231,520          +540        6,335            31  160,000,000
#
#          population
# 225        629,027
# 226
# 227         12,106
# 228          6,116
# 229  1,439,323,776

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.isna().sum()
# Out:
# Country              0
# Total cases          0
# New cases          224
# total deaths         0
# new deaths         225
# total recovered     19
# new recovered      217
# active cases        18
# serious Cases       79
# total test          16
# population           0
# dtype: int64

# %%
df.isna().transpose()
# Out:
#                    0      1      2      3      4      5      6      7    \
# Country          False  False  False  False  False  False  False  False
# Total cases      False  False  False  False  False  False  False  False
# New cases         True   True   True   True   True   True  False   True
# total deaths     False  False  False  False  False  False  False  False
# new deaths        True   True   True   True   True   True  False   True
# total recovered  False  False  False  False  False  False  False  False
# new recovered     True   True   True   True   True  False  False   True
# active cases     False  False  False  False  False  False  False  False
# serious Cases    False  False  False  False  False  False  False  False
# total test       False  False  False  False  False  False  False  False
# population       False  False  False  False  False  False  False  False
#
#                    8      9    ...    220    221    222    223    224    225  \
# Country          False  False  ...  False  False  False  False  False  False
# Total cases      False  False  ...  False  False  False  False  False  False
# New cases         True   True  ...   True   True   True   True   True   True
# total deaths     False  False  ...  False  False  False  False  False  False
# new deaths        True   True  ...   True   True   True   True   True   True
# total recovered  False  False  ...  False  False  False  False  False  False
# new recovered     True   True  ...   True   True   True   True   True   True
# active cases     False  False  ...  False  False  False  False  False  False
# serious Cases    False  False  ...   True   True   True   True   True   True
# total test       False  False  ...  False  False   True   True   True   True
# population       False  False  ...  False  False  False  False  False  False
#
#                    226    227    228    229
# Country          False  False  False  False
# Total cases      False  False  False  False
# New cases         True   True   True  False
# total deaths     False  False  False  False
# new deaths        True   True   True   True
# total recovered  False   True  False  False
# new recovered     True   True   True  False
# active cases     False  False  False  False
# serious Cases     True   True   True  False
# total test        True   True   True  False
# population       False  False  False  False
#
# [11 rows x 230 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isna().transpose())
plt.title("Heatmap of missing data")
plt.show()
plt.close()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isna().transpose())
plt.title("Heatmap of missing data")
plt.xticks([])
# Out:
# ([], [])

# %%
plt.figure(figsize=(10,5))

# %%
df.head(5)
# Out:
#    Country Total cases New cases total deaths  new deaths total recovered  \
# 0      USA  96,149,016       NaN   1,069,748          NaN      91,873,169
# 1    India  44,429,258       NaN     527,829          NaN      43,825,024
# 2   France  34,509,961       NaN     154,039          NaN      33,990,930
# 3   Brazil  34,414,011       NaN     683,914          NaN      33,457,359
# 4  Germany  32,095,854       NaN     147,223          NaN      31,204,400
#
#   new recovered active cases serious Cases     total test      population
# 0           NaN    3,206,099         4,029  1,100,355,942
# 1           NaN       76,405           698    885,528,970  1,409,273,386
# 2           NaN      364,992           869    271,490,188     65,584,999
# 3           NaN      272,738         8,318     63,776,166    215,818,679
# 4           NaN      744,231         1,406    122,332,384     84,361,727

# %%
chunk=df.head()

# %%
chunk
# Out:
#    Country Total cases New cases total deaths  new deaths total recovered  \
# 0      USA  96,149,016       NaN   1,069,748          NaN      91,873,169
# 1    India  44,429,258       NaN     527,829          NaN      43,825,024
# 2   France  34,509,961       NaN     154,039          NaN      33,990,930
# 3   Brazil  34,414,011       NaN     683,914          NaN      33,457,359
# 4  Germany  32,095,854       NaN     147,223          NaN      31,204,400
#
#   new recovered active cases serious Cases     total test      population
# 0           NaN    3,206,099         4,029  1,100,355,942
# 1           NaN       76,405           698    885,528,970  1,409,273,386
# 2           NaN      364,992           869    271,490,188     65,584,999
# 3           NaN      272,738         8,318     63,776,166    215,818,679
# 4           NaN      744,231         1,406    122,332,384     84,361,727

# %%
ax=plt.bar(chunk["Country"],chunk["Total cases"])
